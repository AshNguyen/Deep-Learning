# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from sklearn import datasets
(moon_x, moon_y) = datasets.make_moons(n_samples=10000, noise=0.05, random_state=42)
(circle_x, circle_y) = datasets.make_circles(n_samples=10000, noise=0.025, random_state=42)

# %%
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])


####



model_1 = Sequential()
model_1.add(Dense(32, activation='relu', input_shape=(2,)))
model_1.add(Dense(16, activation='relu'))
model_1.add(Dense(1, activation='sigmoid'))

model_1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
model.fit(moon_x, moon_y, epochs=20, batch_size=256, validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# 8000/8000 [==============================] - 2s 303us/step - loss: 0.6400 - binary_accuracy: 0.7378 - val_loss: 0.5742 - val_binary_accuracy: 0.8495
# Epoch 2/20
# 8000/8000 [==============================] - 0s 17us/step - loss: 0.5264 - binary_accuracy: 0.8504 - val_loss: 0.4721 - val_binary_accuracy: 0.8535
# Epoch 3/20
# 8000/8000 [==============================] - 0s 15us/step - loss: 0.4338 - binary_accuracy: 0.8584 - val_loss: 0.3875 - val_binary_accuracy: 0.8610
# Epoch 4/20
# 8000/8000 [==============================] - 0s 16us/step - loss: 0.3552 - binary_accuracy: 0.8638 - val_loss: 0.3194 - val_binary_accuracy: 0.8690
# Epoch 5/20
# 8000/8000 [==============================] - 0s 15us/step - loss: 0.2994 - binary_accuracy: 0.8725 - val_loss: 0.2773 - val_binary_accuracy: 0.8770
# Epoch 6/20
# ...

# %%
model_1.fit(circle_x, circle_y, epochs=20, batch_size=256, validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# 8000/8000 [==============================] - 2s 297us/step - loss: 0.6884 - binary_accuracy: 0.5075 - val_loss: 0.6848 - val_binary_accuracy: 0.5045
# Epoch 2/20
# 8000/8000 [==============================] - 0s 16us/step - loss: 0.6801 - binary_accuracy: 0.5366 - val_loss: 0.6764 - val_binary_accuracy: 0.5370
# Epoch 3/20
# 8000/8000 [==============================] - 0s 16us/step - loss: 0.6707 - binary_accuracy: 0.5524 - val_loss: 0.6651 - val_binary_accuracy: 0.5100
# Epoch 4/20
# 8000/8000 [==============================] - 0s 18us/step - loss: 0.6569 - binary_accuracy: 0.5827 - val_loss: 0.6473 - val_binary_accuracy: 0.6155
# Epoch 5/20
# 8000/8000 [==============================] - 0s 19us/step - loss: 0.6344 - binary_accuracy: 0.6951 - val_loss: 0.6220 - val_binary_accuracy: 0.7875
# Epoch 6/20
# ...

# %%
def make_meshgrid(x, y, h=.02):
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy

xx, yy = make_meshgrid(moon_x[:,0], moon_x[:,1])

zz = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
zz = zz.reshape(xx.shape)

# %%
# %matplotlib notebook
import matplotlib.colors as mpc
plt.contour(xx, yy, zz, cmap=plt.cm.bone)
colors = ['red','green']
plt.scatter(moon_x[:,0], moon_x[:,1], c=moon_y, cmap=mpc.ListedColormap(colors))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xx_1, yy_1 = make_meshgrid(circle_x[:,0], circle_x[:,1])

zz_1 = model_1.predict_classes(np.c_[xx_1.ravel(), yy_1.ravel()])
zz_1 = zz_1.reshape(xx_1.shape)

# %%
# %matplotlib notebook
plt.contour(xx_1, yy_1, zz_1, cmap=plt.cm.bone)
colors = ['red','green']
plt.scatter(circle_x[:,0], circle_x[:,1], c=moon_y, cmap=mpc.ListedColormap(colors))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
